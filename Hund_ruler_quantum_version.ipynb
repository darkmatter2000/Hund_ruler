# %%
from qiskit import QuantumCircuit, Aer, execute
from qiskit.visualization import plot_histogram

def total_spin(n):
    # Création du circuit quantique
    qc = QuantumCircuit(n)
    
    # Création des qubits pour représenter les spins
    spins = qc.qregs[0]
    
    # Appliquer les portes pour créer les superpositions des spins
    for i in range(n):
        qc.h(spins[i])
    
    # Mesurer les spins
    qc.measure_all()
    
    # Exécution du circuit quantique
    backend = Aer.get_backend('qasm_simulator')
    job = execute(qc, backend, shots=1)
    result = job.result()
    counts = result.get_counts()
    
    # Calcul du spin total
    S = max(counts, key=lambda x: counts[x])  # Le résultat avec la plus grande fréquence
    
    return int(S, 2) - n/2

# %%
total_spin(8)
# Out:
# 149.0

# %%
qc = QuantumCircuit(12)

for i in range(12):
    qc.h(i)

qc.measure_all()
qc.draw()
# Out:
#          ┌───┐ ░ ┌─┐
#     q_0: ┤ H ├─░─┤M├─────────────────────────────────
#          ├───┤ ░ └╥┘┌─┐
#     q_1: ┤ H ├─░──╫─┤M├──────────────────────────────
#          ├───┤ ░  ║ └╥┘┌─┐
#     q_2: ┤ H ├─░──╫──╫─┤M├───────────────────────────
#          ├───┤ ░  ║  ║ └╥┘┌─┐
#     q_3: ┤ H ├─░──╫──╫──╫─┤M├────────────────────────
#          ├───┤ ░  ║  ║  ║ └╥┘┌─┐
#     q_4: ┤ H ├─░──╫──╫──╫──╫─┤M├─────────────────────
#          ├───┤ ░  ║  ║  ║  ║ └╥┘┌─┐
#     q_5: ┤ H ├─░──╫──╫──╫──╫──╫─┤M├──────────────────
#          ├───┤ ░  ║  ║  ║  ║  ║ └╥┘┌─┐
#     q_6: ┤ H ├─░──╫──╫──╫──╫──╫──╫─┤M├───────────────
#          ├───┤ ░  ║  ║  ║  ║  ║  ║ └╥┘┌─┐
#     q_7: ┤ H ├─░──╫──╫──╫──╫──╫──╫──╫─┤M├────────────
#          ├───┤ ░  ║  ║  ║  ║  ║  ║  ║ └╥┘┌─┐
#     q_8: ┤ H ├─░──╫──╫──╫──╫──╫──╫──╫──╫─┤M├─────────
#          ├───┤ ░  ║  ║  ║  ║  ║  ║  ║  ║ └╥┘┌─┐
#     q_9: ┤ H ├─░──╫──╫──╫──╫──╫──╫──╫──╫──╫─┤M├──────
#          ├───┤ ░  ║  ║  ║  ║  ║  ║  ║  ║  ║ └╥┘┌─┐
# ...

# %%
sim = Aer.get_backend('aer_simulator')
result = sim.run(qc).result()
#plot_histogram(result.get_counts())

# %%
backend = Aer.get_backend('statevector_simulator')
job = execute(qc, backend)
result = job.result()
statevector = result.get_statevector()
    
    # Afficher les états et les amplitudes correspondantes
for i, amplitude in enumerate(statevector):
    binary_string = format(i, '0{}b'.format(5))  # Conversion de l'indice en chaîne binaire
    print(f"État : {binary_string}, Amplitude : {amplitude}")
# Out:
# État : 00000, Amplitude : 0j
# État : 00001, Amplitude : 0j
# État : 00010, Amplitude : 0j
# État : 00011, Amplitude : 0j
# État : 00100, Amplitude : 0j
# État : 00101, Amplitude : 0j
# État : 00110, Amplitude : 0j
# État : 00111, Amplitude : 0j
# État : 01000, Amplitude : 0j
# État : 01001, Amplitude : 0j
# État : 01010, Amplitude : 0j
# État : 01011, Amplitude : 0j
# État : 01100, Amplitude : 0j
# État : 01101, Amplitude : 0j
# État : 01110, Amplitude : 0j
# État : 01111, Amplitude : 0j
# État : 10000, Amplitude : 0j
# État : 10001, Amplitude : 0j
# État : 10010, Amplitude : 0j
# État : 10011, Amplitude : 0j
# État : 10100, Amplitude : 0j
# État : 10101, Amplitude : 0j
# État : 10110, Amplitude : 0j
# État : 10111, Amplitude : 0j
# État : 11000, Amplitude : 0j
# État : 11001, Amplitude : 0j
# État : 11010, Amplitude : 0j
# État : 11011, Amplitude : 0j
# État : 11100, Amplitude : 0j
# État : 11101, Amplitude : 0j
# État : 11110, Amplitude : 0j
# État : 11111, Amplitude : 0j
# ...

# %%
print(statevector)
# Out:
# Statevector([0.+0.j, 0.+0.j, 0.+0.j, ..., 0.+0.j, 0.+0.j, 0.+0.j],
#             dims=(2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2))
